# %%
import pandas as pd
import matplotlib.pyplot as plt
from utils import plot_weekly_connection
from utils import plot_cumsum, plot_cumsum_by_gender
from utils import plot_violins, plot_violins_by_gender
from utils import plot_bar_name
# Out:
# /home/yperso/.cache/pypoetry/virtualenvs/linkedin-bOpmuNxz-py3.8/lib/python3.8/site-packages/pandas/compat/__init__.py:117: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
pd.read_csv

# %%
path = '../data/'
file = 'connections_preprocessed.csv'

FIGSIZE = (17, 5)
FONT = {'family': 'sans-serif', 'weight': 'normal', 'size': 16}
tds = "#17b78c"

# %%
df = pd.read_csv(f'{path}{file}')
df.connection_date = pd.to_datetime(df.connection_date)
df.set_index('connection_date', inplace=True, drop=True)
df.sort_index(inplace=True)
df = df.assign(added=1)

# %%
df.head()
# Out:
#                 first_name  males  added
# connection_date
# 2014-10-16            remi   True      1
# 2014-10-16        leprince   True      1
# 2014-10-18       gabrielle  False      1
# 2014-10-21           alain  False      1
# 2014-10-21          karine  False      1

# %%
plot_weekly_connection(df)

# %%
plot_cumsum(df)

# %%
plot_cumsum_by_gender(df)

# %%
plot_violins(df)

# %%
plot_violins_by_gender(df)

# %%
plot_bar_name(df)
